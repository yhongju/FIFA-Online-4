# %%
import pandas as pd

# %% [markdown]
# ## 데이터 불러오기

# %%
df = pd.read_csv("./player_db.csv")
df
# Out:
#              name  pay_side position  overall  \
# 0       크리스티안 겐트너        20       LM       99
# 1         하비 가르시아        18      CDM       95
# 2             요렌테        21       ST      101
# 3          무사 뎀벨레        20       CF       98
# 4        K. 엘아흐마디        17       CM       95
# ...           ...       ...      ...      ...
# 59999     A. 크나우프        13       RM       84
# 60000      K. 야키치        14      CDM       83
# 60001      M. 구스토        12       RB       83
# 60002  G. 마마르다슈빌리        12       GK       85
# 60003        반데르송        13       RM       83
#
#                                                 pomation  \
# 0      98\n97\n98\n97\n97\n99\n99\n99\n99\n99\n98\n99...
# 1      88\n86\n88\n86\n88\n88\n92\n88\n95\n91\n95\n91...
# 2      101\n93\n97\n93\n93\n91\n85\n91\n71\n69\n68\n6...
# 3      97\n97\n98\n97\n97\n97\n93\n97\n86\n86\n82\n86...
# 4      87\n89\n90\n89\n92\n90\n95\n90\n95\n91\n91\n91...
# ...                                                  ...
# ...

# %%
player = pd.read_csv("./player.csv")
player
# Out:
#           id   play_name
# 0          0     데이비드 시먼
# 1          1      앨런 시어러
# 2          2      로비 파울러
# 3          3        로이 킨
# 4          4      라이언 긱스
# ...      ...         ...
# 59046  59046     A. 크나우프
# 59047  59047      K. 야키치
# 59048  59048      M. 구스토
# 59049  59049  G. 마마르다슈빌리
# 59050  59050        반데르송
#
# [59051 rows x 2 columns]

# %%
df[df.name == '데이비드 시먼']
# Out:
#          name  pay_side position  overall  \
# 388   데이비드 시먼        19       GK      101
# 608   데이비드 시먼        19       GK      102
# 2828  데이비드 시먼        20       GK      104
# 2949  데이비드 시먼        15       GK       86
# 3797  데이비드 시먼        13       GK       86
# 4963  데이비드 시먼        16       GK       95
# 6938  데이비드 시먼        15       GK       92
#
#                                                pomation  \
# 388   52\n55\n55\n55\n57\n57\n57\n57\n55\n54\n51\n54...
# 608   49\n52\n51\n52\n54\n54\n55\n54\n53\n52\n49\n52...
# 2828  55\n57\n57\n57\n59\n59\n60\n59\n57\n56\n53\n56...
# 2949  38\n39\n40\n39\n42\n41\n43\n41\n40\n39\n37\n39...
# 3797  41\n41\n42\n41\n44\n44\n45\n44\n42\n41\n39\n41...
# 4963  41\n42\n42\n42\n45\n44\n45\n44\n42\n41\n39\n41...
# 6938  29\n28\n28\n28\n28\n29\n27\n29\n27\n27\n27\n27...
#
#                     skill_swap         etc_birth etc_height etc_weight  \
# 388   특성\nGK 능숙한 펀칭, GK 멀리 던지기  1963.09.19 (60세)      193cm       93kg
# ...

# %%
dfip = pd.read_csv("./data_plus_1.csv")
dfip
# Out:
#           name  pay_side  overall  Sprint_speed  Acceleration  Strength  \
# 0      슈테펜 호프만         5       62            39            51        59
# 1      J. 피에라치         5       60            59            55        68
# 2        누어 허신         5       55            56            61        55
# 3        마오하오위         5       49            69            60        35
# 4      마이크 고메스         5       57            65            61        67
# ...        ...       ...      ...           ...           ...       ...
# 50927      폴 란         6       66            51            56        68
# 50928      크리스         5       62            50            44        59
# 50929     루이스미         5       63            56            54        70
# 50930      시스코         5       63            51            50        78
# 50931       리파         5       62            70            69        64
#
#        Stamina season                                        club_career
# ...

# %% [markdown]
# ## 전처리

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60004 entries, 0 to 60003
# Data columns (total 48 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   name                   60004 non-null  object
#  1   pay_side               60004 non-null  int64
#  2   position               60004 non-null  object
#  3   overall                60004 non-null  int64
#  4   pomation               60004 non-null  object
#  5   skill_swap             60004 non-null  object
#  6   etc_birth              60004 non-null  object
#  7   etc_height             60004 non-null  object
#  8   etc_weight             60004 non-null  object
#  9   etc_physical           60004 non-null  object
#  10  etc_skill              60004 non-null  object
#  11  etc_foot               60004 non-null  object
#  12  etc_nation             60001 non-null  object
#  13  Sprint_speed           60004 non-null  int64
# ...

# %%
test_df = df.drop_duplicates()

# %%
test_df[test_df.name == '데이비드 시먼']
# Out:
#          name  pay_side position  overall  \
# 388   데이비드 시먼        19       GK      101
# 608   데이비드 시먼        19       GK      102
# 2828  데이비드 시먼        20       GK      104
# 2949  데이비드 시먼        15       GK       86
# 3797  데이비드 시먼        13       GK       86
# 4963  데이비드 시먼        16       GK       95
# 6938  데이비드 시먼        15       GK       92
#
#                                                pomation  \
# 388   52\n55\n55\n55\n57\n57\n57\n57\n55\n54\n51\n54...
# 608   49\n52\n51\n52\n54\n54\n55\n54\n53\n52\n49\n52...
# 2828  55\n57\n57\n57\n59\n59\n60\n59\n57\n56\n53\n56...
# 2949  38\n39\n40\n39\n42\n41\n43\n41\n40\n39\n37\n39...
# 3797  41\n41\n42\n41\n44\n44\n45\n44\n42\n41\n39\n41...
# 4963  41\n42\n42\n42\n45\n44\n45\n44\n42\n41\n39\n41...
# 6938  29\n28\n28\n28\n28\n29\n27\n29\n27\n27\n27\n27...
#
#                     skill_swap         etc_birth etc_height etc_weight  \
# 388   특성\nGK 능숙한 펀칭, GK 멀리 던지기  1963.09.19 (60세)      193cm       93kg
# ...

# %%
player
# Out:
#           id   play_name
# 0          0     데이비드 시먼
# 1          1      앨런 시어러
# 2          2      로비 파울러
# 3          3        로이 킨
# 4          4      라이언 긱스
# ...      ...         ...
# 59046  59046     A. 크나우프
# 59047  59047      K. 야키치
# 59048  59048      M. 구스토
# 59049  59049  G. 마마르다슈빌리
# 59050  59050        반데르송
#
# [59051 rows x 2 columns]

# %%
dfip = dfip[['name', 'pay_side', 'overall', 'Sprint_speed', 'season']]

# %%
test_2 = pd.merge(left=df, right=dfip, how='left', \
                  on=['name', 'pay_side', 'overall'], sort=False)
test_2
# Out:
#              name  pay_side position  overall  \
# 0       크리스티안 겐트너        20       LM       99
# 1         하비 가르시아        18      CDM       95
# 2             요렌테        21       ST      101
# 3          무사 뎀벨레        20       CF       98
# 4        K. 엘아흐마디        17       CM       95
# ...           ...       ...      ...      ...
# 64937     A. 크나우프        13       RM       84
# 64938      K. 야키치        14      CDM       83
# 64939      M. 구스토        12       RB       83
# 64940  G. 마마르다슈빌리        12       GK       85
# 64941        반데르송        13       RM       83
#
#                                                 pomation  \
# 0      98\n97\n98\n97\n97\n99\n99\n99\n99\n99\n98\n99...
# 1      88\n86\n88\n86\n88\n88\n92\n88\n95\n91\n95\n91...
# 2      101\n93\n97\n93\n93\n91\n85\n91\n71\n69\n68\n6...
# 3      97\n97\n98\n97\n97\n97\n93\n97\n86\n86\n82\n86...
# 4      87\n89\n90\n89\n92\n90\n95\n90\n95\n91\n91\n91...
# ...                                                  ...
# ...

# %%
test_2[test_2.name == '데이비드 시먼']
# Out:
#          name  pay_side position  overall  \
# 463   데이비드 시먼        19       GK      101
# 726   데이비드 시먼        19       GK      102
# 3380  데이비드 시먼        20       GK      104
# 3512  데이비드 시먼        15       GK       86
# 4475  데이비드 시먼        13       GK       86
# 5827  데이비드 시먼        16       GK       95
# 8022  데이비드 시먼        15       GK       92
#
#                                                pomation  \
# 463   52\n55\n55\n55\n57\n57\n57\n57\n55\n54\n51\n54...
# 726   49\n52\n51\n52\n54\n54\n55\n54\n53\n52\n49\n52...
# 3380  55\n57\n57\n57\n59\n59\n60\n59\n57\n56\n53\n56...
# 3512  38\n39\n40\n39\n42\n41\n43\n41\n40\n39\n37\n39...
# 4475  41\n41\n42\n41\n44\n44\n45\n44\n42\n41\n39\n41...
# 5827  41\n42\n42\n42\n45\n44\n45\n44\n42\n41\n39\n41...
# 8022  29\n28\n28\n28\n28\n29\n27\n29\n27\n27\n27\n27...
#
#                     skill_swap         etc_birth etc_height etc_weight  \
# 463   특성\nGK 능숙한 펀칭, GK 멀리 던지기  1963.09.19 (60세)      193cm       93kg
# ...

# %%
test_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64942 entries, 0 to 64941
# Data columns (total 54 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   name                   64942 non-null  object
#  1   pay_side               64942 non-null  int64
#  2   position               64942 non-null  object
#  3   overall                64942 non-null  int64
#  4   pomation               64942 non-null  object
#  5   skill_swap             64942 non-null  object
#  6   etc_birth              64942 non-null  object
#  7   etc_height             64942 non-null  object
#  8   etc_weight             64942 non-null  object
#  9   etc_physical           64942 non-null  object
#  10  etc_skill              64942 non-null  object
#  11  etc_foot               64942 non-null  object
#  12  etc_nation             64939 non-null  object
#  13  Sprint_speed_x         64942 non-null  int64
# ...

# %%
test_2.drop_duplicates()
# Out:
#              name  pay_side position  overall  \
# 0       크리스티안 겐트너        20       LM       99
# 1         하비 가르시아        18      CDM       95
# 2             요렌테        21       ST      101
# 3          무사 뎀벨레        20       CF       98
# 4        K. 엘아흐마디        17       CM       95
# ...           ...       ...      ...      ...
# 64937     A. 크나우프        13       RM       84
# 64938      K. 야키치        14      CDM       83
# 64939      M. 구스토        12       RB       83
# 64940  G. 마마르다슈빌리        12       GK       85
# 64941        반데르송        13       RM       83
#
#                                                 pomation  \
# 0      98\n97\n98\n97\n97\n99\n99\n99\n99\n99\n98\n99...
# 1      88\n86\n88\n86\n88\n88\n92\n88\n95\n91\n95\n91...
# 2      101\n93\n97\n93\n93\n91\n85\n91\n71\n69\n68\n6...
# 3      97\n97\n98\n97\n97\n97\n93\n97\n86\n86\n82\n86...
# 4      87\n89\n90\n89\n92\n90\n95\n90\n95\n91\n91\n91...
# ...                                                  ...
# ...

# %%
test = test_2.drop(['Sprint_speed_y', 'Acceleration_y', 'Strength_y', 'Stamina_y'], axis=1)

# %%
test.club_career[0]
# Out:
# "['2019 ~ 2021 / FC 루체른', '2010 ~ 2019 / 1. FC 우니온 베를린', '2008 ~ 2010 / VfB 슈투트가르트', '2005 ~ 2008 / VfL 볼프스부르크', '2007 ~ 2008 / VfB 슈투트가르트', '임대 / VfL 볼프스부르크']"

# %%
test.pomation[0]
# Out:
# '98\n97\n98\n97\n97\n99\n99\n99\n99\n99\n98\n99\n98\n97\n98\n27'

# %%
test.skill_swap[0]
# Out:
# '특성\n유리몸, 슬라이딩 태클 선호'

# %%
dfip.overall.apply(split('\n'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 dfip.overall.apply(split('\n'))
#
# NameError: name 'split' is not defined

# %%
dfip['overall']=dfip['overall'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 dfip['overall']=dfip['overall'].astype(int)
#
# File ~/miniforge3/envs/fifa_project/lib/python3.8/site-packages/pandas/core/generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File ~/miniforge3/envs/fifa_project/lib/python3.8/site-packages/pandas/core/internals/managers.py:450, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
for i in dfip.overall:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 for i in dfip.overall:
#       2     print(i)
#
# AttributeError: 'NoneType' object has no attribute 'overall'

# %%
test = test[['name', 'price', 'pay_side_y', 'overall_y', 'season']]
test.drop_duplicates()[test.drop_duplicates().name == '데이비드 시먼']
# Out:
#           name           price  pay_side_y overall_y season
# 1303   데이비드 시먼   71,800,000 BP          19       101    EBS
# 1862   데이비드 시먼   89,800,000 BP          19       102    CAP
# 7316   데이비드 시먼  800,000,000 BP          20       104   ICON
# 7317   데이비드 시먼  800,000,000 BP          16        95    HOT
# 7318   데이비드 시먼  800,000,000 BP          15        92     LH
# 7319   데이비드 시먼   18,100,000 BP          20       104   ICON
# 7320   데이비드 시먼   18,100,000 BP          16        95    HOT
# 7321   데이비드 시먼   18,100,000 BP          15        92     LH
# 7322   데이비드 시먼   13,200,000 BP          20       104   ICON
# 7323   데이비드 시먼   13,200,000 BP          16        95    HOT
# 7324   데이비드 시먼   13,200,000 BP          15        92     LH
# 7525   데이비드 시먼    5,030,000 BP          15        86    NHD
# 11104  데이비드 시먼    4,460,000 BP          13        86     TT
